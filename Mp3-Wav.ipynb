# %%
import os
from pydub import AudioSegment

def convert_mp3_to_wav(directory):
    # Iterate over all files in the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.mp3'):
                mp3_path = os.path.join(root, file)
                wav_path = os.path.splitext(mp3_path)[0] + '.wav'
                
                # Convert mp3 to wav
                audio = AudioSegment.from_mp3(mp3_path)
                audio.export(wav_path, format='wav')
                
                # Delete the original mp3 file
                os.remove(mp3_path)
                print(f"Converted and deleted: {mp3_path}")

# Specify the path to your dataset directory
dataset_directory = r"D:\Tag\Genre Classifier\Data\genres_original\folk"
convert_mp3_to_wav(dataset_directory)
# Out:
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Ae Re Sakhi.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Aisi Mhari Preet (Eternal Love) - Sabr.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Bhammariyo.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Boondan Boondan (feat. Ankita Joshi).mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Chamba Kitni Door.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Chhaap Tilak.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Chhap Tilak.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Dilruba.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Ek Nazar.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\folk\Ekla Cholo Re.mp3
# ...

# %%
import os
from pydub import AudioSegment

def convert_mp3_to_wav(directory):
    # Iterate over all files in the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.mp3'):
                mp3_path = os.path.join(root, file)
                wav_path = os.path.splitext(mp3_path)[0] + '.wav'
                
                # Convert mp3 to wav
                audio = AudioSegment.from_mp3(mp3_path)
                audio.export(wav_path, format='wav')
                
                # Delete the original mp3 file
                os.remove(mp3_path)
                print(f"Converted and deleted: {mp3_path}")

# Specify the path to your dataset directory
dataset_directory = r"D:\Tag\Genre Classifier\Data\genres_original\soulful"
convert_mp3_to_wav(dataset_directory)
# Out:
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\A Change Is Gonna Come - Mono; 2008 Remaster.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\A Woman Needs Love (Just Like You Do).mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\After All.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\Ain't No Woman (Like The One I've Got).mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\All This Love.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\Always and Forever.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\Back to your Place.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\Being With You.mp3
# Converted and deleted: D:\Tag\Genre Classifier\Data\genres_original\soulful\Caught Up in the Rapture.mp3
# ...
